# %% [markdown]
# # HAPPY DF

# %% [raw]
# CONTENIDO DE LOS DATOS
#
# Las puntuaciones y clasificaciones de felicidad utilizan datos de la Encuesta mundial de Gallup.
# Encuesta mundial de Gallup: en 2005, Gallup inició la Encuesta mundial, que continuamente encuesta a ciudadanos en 160 países que representan más del 98% de la población adulta mundial. La Encuesta mundial de Gallup consta de más de 100 preguntas globales, así como elementos específicos de la región.
# Las columnas que siguen al puntaje de felicidad estiman la medida en que cada uno de los seis factores (producción económica, apoyo social, esperanza de vida, libertad, ausencia de corrupción y generosidad) contribuye a que los puntajes de vida sean más altos en cada país que en Dystopia. país hipotético con valores iguales a los promedios nacionales más bajos del mundo para cada uno de los seis factores.
#
# -Ladder score: Puntaje de felicidad o bienestar subjetivo.
#
# -Standard error of ladder score: Serie temporal del PIB per cápita de 2019 a 2020 utilizando pronósticos específicos del país del crecimiento del PIB real en 2020.
#
# -Apoyo social: El apoyo social se refiere a la ayuda o apoyo que brindan a un individuo los miembros de las redes sociales.
#
# -Esperanza de vida saludable: La esperanza de vida saludable es la esperanza de vida promedio de una generación ficticia con buena salud, es decir, sin limitación irreversible o discapacidad en la vida diaria, sujeta a las condiciones de muerte y enfermedad prevalecientes en ese año.
#
# -Libertad para tomar decisiones en la vida: La libertad para tomar decisiones en la vida, el GWP "¿Está satisfecho o insatisfecho con la libertad de elegir qué hacer con su vida?" Es el promedio nacional de las respuestas por pares a la pregunta. ... Se define como la media de la risa y el disfrute de otras olas donde no se plantea la cuestión de la felicidad.
#
# -Generosidad: Generosidad, GWP's "¿Donaste a una organización benéfica el mes pasado?" Es el remanente de la caída en el promedio nacional de respuestas a la pregunta. sobre el PIB per cápita.
#
# -Percepciones de corrupción: la medida es el promedio nacional de las respuestas de la encuesta a dos preguntas en el GWP: "¿Prevalece la corrupción en todo el gobierno?" y "¿Es común la corrupción en las empresas?"

# %% [markdown]
# ## Importaciones y carga de datos

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')                  # para quitar warnings

pd.set_option('display.max_columns', None)         # muestra todas las columnas del df.head()

# %%
df= pd.read_csv(r'C:\Users\Oriana Ampuero\ironhack\semana5\world-happiness-report-2021.csv')

df.head(10)
# Out:
#   Country name     Regional indicator  Ladder score  \
# 0      Finland         Western Europe         7.842
# 1      Denmark         Western Europe         7.620
# 2  Switzerland         Western Europe         7.571
# 3      Iceland         Western Europe         7.554
# 4  Netherlands         Western Europe         7.464
# 5       Norway         Western Europe         7.392
# 6       Sweden         Western Europe         7.363
# 7   Luxembourg         Western Europe         7.324
# 8  New Zealand  North America and ANZ         7.277
# 9      Austria         Western Europe         7.268
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
# ...

# %% [markdown]
# ## Exploración

# %%
# dimensiones del dataframe

dim_original= df.shape

df.shape
# Out:
# (149, 20)

# %%
# información del df

df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %%
df.describe().T
# Out:
#                                             count       mean           std  \
# Ladder score                                149.0   5.532839  1.073924e+00
# Standard error of ladder score              149.0   0.058752  2.200120e-02
# upperwhisker                                149.0   5.648007  1.054330e+00
# lowerwhisker                                149.0   5.417631  1.094879e+00
# Logged GDP per capita                       149.0   9.432208  1.158601e+00
# Social support                              149.0   0.814745  1.148890e-01
# Healthy life expectancy                     149.0  64.992799  6.762043e+00
# Freedom to make life choices                149.0   0.791597  1.133318e-01
# Generosity                                  149.0  -0.015134  1.506567e-01
# Perceptions of corruption                   149.0   0.727450  1.792263e-01
# Ladder score in Dystopia                    149.0   2.430000  5.347044e-15
# ...

# %%
df.to_csv(r'C:\Users\Oriana Ampuero\ironhack\semana5\PROJECT4\DATA\happy.csv', index = False)
